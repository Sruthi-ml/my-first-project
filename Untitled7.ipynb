# %%
messages = [line.rstrip() for line in open('SMSSpamCollection')]
print(len(messages))
# Out:
# 5574

# %%
for message_no, message in enumerate(messages[:10]):
    print(message_no,message)
    print('\n')
# Out:
# 0 ham	Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
#
#
# 1 ham	Ok lar... Joking wif u oni...
#
#
# 2 spam	Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
#
#
# 3 ham	U dun say so early hor... U c already then say...
#
#
# 4 ham	Nah I don't think he goes to usf, he lives around here though
#
#
# 5 spam	FreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send, Â£1.50 to rcv
#
#
# 6 ham	Even my brother is not like to speak with me. They treat me like aids patent.
#
#
# 7 ham	As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune
#
#
# ...

# %%
import pandas as pd
messages= pd.read_csv('SMSSpamCollection',names=['label','messgae'])
messages.head()
# Out:
#                                                label  \
# 0                         ham\tGo until jurong point
# 1                 ham\tOk lar... Joking wif u oni...
# 2  spam\tFree entry in 2 a wkly comp to win FA Cu...
# 3  ham\tU dun say so early hor... U c already the...
# 4              ham\tNah I don't think he goes to usf
#
#                                              messgae
# 0   crazy.. Available only in bugis n great world...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                        he lives around here though

# %%
messages_class =messages[messages['length']==910]['message'].iloc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'length'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-99261995f4e0> in <module>()
# ...

# %%
msg=messages_class['message']
label=messages_class['label']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'message'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-999ccd8d54c4> in <module>()
# ----> 1 msg=messages['message']
# ...

# %%
messages.describe()
# Out:
#              label           messgae
# count         5574              1318
# unique        4969              1153
# top     ham\tSorry   I'll call later
# freq            52                30

# %%
message.groupby('label').describe()
# Out:
#                                                    messgae       \
#                                                      count freq
# label
# ham\t                                                    4    1
# ham\t &lt;#&gt;  in mca. But not conform.                0  NaN
# ham\t &lt;#&gt;  mins but i had to stop somewhe...       0  NaN
# ham\t &lt;DECIMAL&gt; m but its not a common ca...       0  NaN
# ham\t and  picking them up from various points           0  NaN
# ham\t came to look at the flat                           1    1
# ham\t gonna let me know cos comes bak from holi...       0  NaN
# ham\t said kiss                                          1    1
# ham\t says that he's quitting at least5times a ...       1    1
# ham\t what number do u live at? Is it 11?                0  NaN
# ham\t"AH POOR BABY!HOPE URFEELING BETTERSN LUV!...       0  NaN
# ham\t"ALRITE HUNNY!WOT U UP 2 2NITE? DIDNT END ...       0  NaN
# ...

# %%
message['length'] = message['message'].str.len()
message.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'message'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-8e9276b06612> in <module>()
# ...

# %%
messages = pd.read_csv('SMSSpamCollection', names=['label', 'message'], sep='\t')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
message['length'].plot(bins=50, kind='hist')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'length'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-95-ed5b22723eb6> in <module>()
# ...

# %%
message.length.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-a45ca0ad8fe5> in <module>()
# ----> 1 message.length.describe()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'length'

# %%
message[message['length']==910]['message'].iloc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'length'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-cf04632ce534> in <module>()
# ...

# %%
message.hist(column='length', bye='label',bins=50,figsize=(12,4))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-5ffa68b7af52> in <module>()
# ----> 1 message.hist(column='length', bye='label',bins=50,figsize=(12,4))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#    2400         if not isinstance(column, (list, np.ndarray, Index)):
#    2401             column = [column]
# -> 2402         data = data[column]
#    2403     data = data._get_numeric_data()
#    2404     naxes = len(data.columns)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
# ...

# %%
import string

mess = 'Sample message! Notice: it has punctuation.'

nopunc = [char for char in mess if char not in string.punctuation]

nonpunc=''.join(nopunc)

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stopwords.words('english')[0:10]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Sruthi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
clean_mess=[word for word in nopunc.split() if word.lower() not in stopwords.words('english')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-73b69392f18c> in <module>()
# ----> 1 clean_mess=[word for word in nopunc.split() if word.lower() not in stopwords.words('english')]
#
# AttributeError: 'list' object has no attribute 'split'

# %%
clean_mess
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-e0bc034ab443> in <module>()
# ----> 1 clean_mess
#
# NameError: name 'clean_mess' is not defined

# %%
def text_process(mess):
    nopunc=[char for char in mess if char not in string.punctuation]
    nopunc=''.join(nopunc)
    return[word for word in nopunc.split if word.lower() not in stopwords.words('english')]

# %%
message['message'].head(5).apply(text_process)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'message'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-84-867e6d230329> in <module>()
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
bow_transformer = CountVectorizer(analyzer = text_process).fit(message['message'])

print(len(bow_transformer.vocabulary_))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'message'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-e779234ec4fe> in <module>()
# ...

# %%
message4 = message['message'][3]
print(message4)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'message'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-77c4a47b2983> in <module>()
# ...

# %%
bow4 = bow_transformer.transform([message4])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-97-4d9c6f4e2b93> in <module>()
# ----> 1 bow4 = bow_transformer.transform([message4])
#
# NameError: name 'bow_transformer' is not defined

# %% [raw]
# print(bow-transformer.get_feature_names()[4073]
# print(bow-transformer.get_feature_names()[9570]

# %%
messages_bow = bow_transformer.transform(message['message'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-98-e142a59861c6> in <module>()
# ----> 1 messages_bow = bow_transformer.transform(message['message'])
#
# NameError: name 'bow_transformer' is not defined
